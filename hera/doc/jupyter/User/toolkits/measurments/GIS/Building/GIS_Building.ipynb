# %%
from hera import toolkitHome

gis_building_tk = toolkitHome.getToolkit(toolkitName=toolkitHome.GIS_BUILDINGS)

# %%
from hera.utils.logging import initialize_logging,with_logger
initialize_logging(
          with_logger("hera.measurements.GIS.vector.buildings.analysis", handlers=['console'], level='INFO', propagate=False)
    )

# %%
gis_building_tk.getDataSourceList()
# Out:
# ['BNTL']

# %% [markdown]
# ### getBuildingsFromRectangle

# %%
from hera.measurements.GIS.utils import WSG84,ITM,convertCRS

north_tel_aviv_buildings = gis_building_tk.getBuildingsFromRectangle(minx=180000, miny=668000, maxx=183000, maxy=670500 , inputCRS=ITM)
north_tel_aviv_buildings
# Out:
#        UNIQ_ID   PARENT  FCODE  FTYPE       HI_PNT_X       HI_PNT_Y  HI_PNT_Z  \
# 0     51662710  4045779    201     11  181527.765627  668513.934994     48.90
# 1     53183368  4045109    201     11  181037.685627  668802.330094     21.70
# 2     51662378  4046436    201     11  181040.672127  668251.141494     20.61
# 3     51662411  4043929    201     11  183025.576627  669250.286294     36.38
# 4     51662441  4044930    201     11  181510.795027  668875.254394     41.29
# ...        ...      ...    ...    ...            ...            ...       ...
# 2552  64751837        0    201     11       0.000000       0.000000      0.00
# 2553  64750892        0    201     11       0.000000       0.000000      0.00
# 2554  64751446        0    201     11       0.000000       0.000000      0.00
# 2555  64751447        0    201     11       0.000000       0.000000      0.00
# 2556  64751448        0    201     11       0.000000       0.000000      0.00
#
#       HEIGHT  HT_LAND FNAME  ... BLDG_HT   ADDR_ID  ADDR_COUNT    USG_ID  \
# 0     42.420    31.48  None  ...  10.940  53899844           1         0
# 1     20.000    13.27  None  ...   6.730  53696199           5  54001440
# 2     19.500    17.02  None  ...   2.480  53700122           3  53988238
# 3     32.455    19.17  None  ...  13.285         0           0         0
# 4     32.050    21.14  None  ...  10.910         0           0         0
# ...      ...      ...   ...  ...     ...       ...         ...       ...
# 2552   0.000     0.00  None  ...   0.000         0           0         0
# 2553   0.000     0.00  None  ...   0.000         0           0         0
# 2554   0.000     0.00  None  ...   0.000         0           0         0
# 2555   0.000     0.00  None  ...   0.000         0           0         0
# 2556   0.000     0.00  None  ...   0.000         0           0         0
#
#       CMPLX_ID  CMLX_FCD    ORIG_AREA  SHAPE_Leng   SHAPE_Area  \
# 0     54446777       251  5545.413150  480.027290  5545.413150
# 1            0         0  3766.161650  282.160516  3766.161650
# 2     60590888       251  3068.145250  375.792577  3068.145250
# 3     54447761       251  4551.408400  361.256724  4551.408400
# 4     54446171       251  3066.480000  229.180000  3066.480000
# ...        ...       ...          ...         ...          ...
# 2552  54446187       251  1606.780635  166.626180  1606.780635
# 2553  51592690       151    42.428500   30.779423    42.428500
# 2554  54446559       251   421.084248   90.910951   421.084248
# 2555         0         0   149.703559   49.275173   149.703559
# 2556         0         0  1275.258234  142.887600  1275.258234
#
#                                                geometry
# 0     POLYGON ((181497.300 668484.380, 181488.500 66...
# 1     POLYGON ((180967.880 668759.000, 180961.720 66...
# 2     POLYGON ((181040.800 668212.880, 180996.300 66...
# 3     POLYGON ((182987.910 669226.810, 182976.090 66...
# 4     POLYGON ((181532.090 668834.810, 181489.500 66...
# ...                                                 ...
# 2552  POLYGON ((182063.327 668012.156, 182038.720 66...
# 2553  POLYGON ((179988.974 668134.125, 179989.523 66...
# 2554  POLYGON ((182764.202 669901.553, 182741.977 66...
# 2555  POLYGON ((182500.005 669240.735, 182493.909 66...
# 2556  POLYGON ((180014.728 669157.358, 180036.381 66...
#
# [2557 rows x 21 columns]

# %% [markdown]
# ### LambdaFromBuildingData

# %% [markdown]
# You can meassure the lambdas for a squares of GIS geopandas. Deafault it true of cache option:

# %%
north_tel_aviv_buildings.crs = ITM
north_tel_aviv_buildings_lambdas = gis_building_tk.analysis.LambdaFromBuildingData(23,500,north_tel_aviv_buildings)
north_tel_aviv_buildings_lambdas
# Out:
# INFO    : analysis.py/LambdaFromBuildingData(113) --- Start ---
# INFO    : analysis.py/LambdaFromBuildingData(138) Check if cached data exists for data {'bounds': array([179902.00002654, 667938.4999939 , 183074.80002654, 670563.4999939 ]), 'wind': 23, 'resolution': 500, 'crs': 2039}
# INFO    : analysis.py/LambdaFromBuildingData(176) ---- End ----
#      lambdaP   lambdaF         hc  i0  j0  \
# 0   0.082781  0.077146  16.587096   0   0
# 1   0.045804  0.056140  21.652310   0   1
# 2   0.113593  0.199018  32.050530   0   2
# 3   0.015242  0.023897  27.851290   0   3
# 4   0.000000  0.000000   0.000000   0   4
# 5   0.000000  0.000000   0.000000   0   5
# 6   0.113938  0.117305  13.340440   1   0
# 7   0.166829  0.162258  16.557517   1   1
# 8   0.181426  0.199902  20.165166   1   2
# 9   0.144462  0.165506  23.097431   1   3
# 10  0.034035  0.056473  35.835401   1   4
# 11  0.060166  0.066114  32.580033   1   5
# 12  0.171355  0.088916   8.282732   2   0
# 13  0.239184  0.151227  10.337291   2   1
# 14  0.158016  0.137355  13.646505   2   2
# 15  0.141938  0.170612  21.282791   2   3
# 16  0.127695  0.188672  28.993836   2   4
# 17  0.114501  0.181464  33.874450   2   5
# 18  0.030354  0.015798   8.144174   3   0
# 19  0.225493  0.130301  13.649872   3   1
# 20  0.158697  0.070411  11.707236   3   2
# 21  0.134433  0.103885  10.322900   3   3
# 22  0.172332  0.176152  19.223395   3   4
# 23  0.135172  0.108578  16.593878   3   5
# 24  0.099160  0.020865   9.521982   4   0
# 25  0.043676  0.020919   8.080031   4   1
# 26  0.093580  0.040630   7.875910   4   2
# 27  0.123654  0.068817   5.688487   4   3
# 28  0.116029  0.078681  10.144680   4   4
# 29  0.056753  0.061074  11.611610   4   5
# 30  0.023776  0.009369   4.400331   5   0
# 31  0.090927  0.079527   9.913007   5   1
# 32  0.190633  0.116391   7.009064   5   2
# 33  0.203844  0.107264   6.478528   5   3
# 34  0.136444  0.131695  18.722242   5   4
# 35  0.000000  0.000000   0.000000   5   5
# 36  0.081402  0.040949   6.117331   6   0
# 37  0.120006  0.090172   8.463812   6   1
# 38  0.159377  0.052951   9.477706   6   2
# 39  0.123180  0.070564   6.307918   6   3
# 40  0.096919  0.098343  15.731051   6   4
# 41  0.000000  0.000000   0.000000   6   5
#
#                                              geometry
# 0   POLYGON ((180402.000 667938.500, 180402.000 66...
# 1   POLYGON ((180402.000 668438.500, 180402.000 66...
# 2   POLYGON ((180402.000 668938.500, 180402.000 66...
# 3   POLYGON ((180402.000 669438.500, 180402.000 66...
# 4   POLYGON ((180402.000 669938.500, 180402.000 67...
# 5   POLYGON ((180402.000 670438.500, 180402.000 67...
# 6   POLYGON ((180902.000 667938.500, 180902.000 66...
# 7   POLYGON ((180902.000 668438.500, 180902.000 66...
# 8   POLYGON ((180902.000 668938.500, 180902.000 66...
# 9   POLYGON ((180902.000 669438.500, 180902.000 66...
# 10  POLYGON ((180902.000 669938.500, 180902.000 67...
# 11  POLYGON ((180902.000 670438.500, 180902.000 67...
# 12  POLYGON ((181402.000 667938.500, 181402.000 66...
# 13  POLYGON ((181402.000 668438.500, 181402.000 66...
# 14  POLYGON ((181402.000 668938.500, 181402.000 66...
# 15  POLYGON ((181402.000 669438.500, 181402.000 66...
# 16  POLYGON ((181402.000 669938.500, 181402.000 67...
# 17  POLYGON ((181402.000 670438.500, 181402.000 67...
# 18  POLYGON ((181902.000 667938.500, 181902.000 66...
# 19  POLYGON ((181902.000 668438.500, 181902.000 66...
# 20  POLYGON ((181902.000 668938.500, 181902.000 66...
# 21  POLYGON ((181902.000 669438.500, 181902.000 66...
# 22  POLYGON ((181902.000 669938.500, 181902.000 67...
# 23  POLYGON ((181902.000 670438.500, 181902.000 67...
# 24  POLYGON ((182402.000 667938.500, 182402.000 66...
# 25  POLYGON ((182402.000 668438.500, 182402.000 66...
# 26  POLYGON ((182402.000 668938.500, 182402.000 66...
# 27  POLYGON ((182402.000 669438.500, 182402.000 66...
# 28  POLYGON ((182402.000 669938.500, 182402.000 67...
# 29  POLYGON ((182402.000 670438.500, 182402.000 67...
# 30  POLYGON ((182902.000 667938.500, 182902.000 66...
# 31  POLYGON ((182902.000 668438.500, 182902.000 66...
# 32  POLYGON ((182902.000 668938.500, 182902.000 66...
# 33  POLYGON ((182902.000 669438.500, 182902.000 66...
# 34  POLYGON ((182902.000 669938.500, 182902.000 67...
# 35  POLYGON ((182902.000 670438.500, 182902.000 67...
# 36  POLYGON ((183074.800 667938.500, 183074.800 66...
# 37  POLYGON ((183074.800 668438.500, 183074.800 66...
# 38  POLYGON ((183074.800 668938.500, 183074.800 66...
# 39  POLYGON ((183074.800 669438.500, 183074.800 66...
# 40  POLYGON ((183074.800 669938.500, 183074.800 67...
# 41  POLYGON ((183074.800 670438.500, 183074.800 67...

# %% [markdown]
# You can also meassure the lambdas for a squares of GIS geopandas with the default datasource.

# %%
gis_building_tk.getConfig()['defaultBuildingDataSource']
# Out:
# 'BNTL'

# %% [markdown]
# If you wish to not use caching, simply use cache=False.

# %% [markdown]
# ### buildingsGeopandasToSTLRasterTopography

# %%
import os

current_file = os.path.dirname(os.path.abspath(os.getcwd())) + '/Landcover/STL.stl'

# %%
gis_building_tk.buildingsGeopandasToSTLRasterTopography(datasource.iloc[1:5],'HEIGHT','HI_PNT_Z',current_file)

# %%
sqaure = gis_building_tk.analysis.LambdaFromBuildingData(23,12,datasource.iloc[1:2])['geometry'].iloc[0]
# Out:
# INFO    : analysis.py/LambdaFromBuildingData(113) --- Start ---
# INFO    : analysis.py/LambdaFromBuildingData(138) Check if cached data exists for data {'bounds': array([184801.50002654, 675301.8099939 , 184885.80002654, 675362.8099939 ]), 'wind': 23, 'resolution': 12, 'crs': 2039}
# INFO    : analysis.py/LambdaFromBuildingData(176) ---- End ----

# %%
sqaure.exterior.coords.xy
# Out:
# (array('d', [184813.50002653955, 184813.50002653955, 184801.50002653955, 184801.50002653955, 184813.50002653955]),
#  array('d', [675301.8099938995, 675313.8099938995, 675313.8099938995, 675301.8099938995, 675301.8099938995]))

# %% [markdown]
# ## Convex Hull Plot

# %%
import geopandas as gpd

# Assuming your GeoDataFrame 'gdf' is already loaded with a 'geometry' column
datasource['convex_hull'] = datasource['geometry'].convex_hull

# Extract the coordinates of the convex hull
datasource['hullS_coords'] = datasource['convex_hull'].apply(lambda x: list(x.exterior.coords))

# Optional: Plot the original buildings and their convex hulls
datasource.set_geometry('convex_hull').plot()
# Out:
# <Axes: >

# %%
datasource['hullS_coords']
# Out:
# 0         [(179000.91002653955, 658933.1899938995), (178...
# 1         [(184877.30002653957, 675301.8099938995), (184...
# 2         [(190143.39002653956, 664286.8799938995), (190...
# 3         [(178607.45672653956, 663849.9666938995), (178...
# 4         [(180154.30002653957, 663212.8799938995), (180...
#                                 ...
# 156674    [(185490.34462653956, 673139.9937938995), (185...
# 156675    [(184309.78772653957, 675243.8870938995), (184...
# 156676    [(176530.83382653957, 662209.1784938995), (176...
# 156677    [(183854.20002653956, 671397.1899938995), (183...
# 156678    [(178399.30002653957, 662644.4999938995), (178...
# Name: hullS_coords, Length: 156679, dtype: object

# %%
list(gis_building_tk.analysis.LambdaFromBuildingData(23,12,datasource.iloc[1:2]).iloc[0]['geometry'].exterior.coords)
# Out:
# INFO    : analysis.py/LambdaFromBuildingData(113) --- Start ---
# INFO    : analysis.py/LambdaFromBuildingData(138) Check if cached data exists for data {'bounds': array([184801.50002654, 675301.8099939 , 184885.80002654, 675362.8099939 ]), 'wind': 23, 'resolution': 12, 'crs': 2039}
# INFO    : analysis.py/LambdaFromBuildingData(176) ---- End ----
# [(184813.50002653955, 675301.8099938995),
#  (184813.50002653955, 675313.8099938995),
#  (184801.50002653955, 675313.8099938995),
#  (184801.50002653955, 675301.8099938995),
#  (184813.50002653955, 675301.8099938995)]
