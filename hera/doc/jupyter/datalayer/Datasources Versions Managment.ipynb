# %% [markdown]
# # Datasources Default Version Managment
#
# This notebook provides a quick and simple guide to setting and updating the default versions of datasources.

# %% [markdown]
# ### Why to use it
# Setting default datasource versions enhances convenience and streamlines your workflow. Here's why and when to use it:
#
# - Datasource multiple Versions:
# When a datasource has multiple versions, the toolkit defaults to using the highest version unless a specific default is set.
#
# - Simplified Workflow:
# If you frequently use a particular version, specifying it every time can be cumbersome. Setting a default version ensures that the toolkit automatically selects your preferred version without requiring manual input.
#
# By setting a default version, you can bypass repetitive configuration and focus on your tasks more efficiently.

# %% [markdown]
# ## CLI
# Using the CLI, we can display, set and update the default datasources.

# %% [markdown]
# ### Display

# %%
from hera import toolkitHome
from hera.datalayer import datatypes


projectName = "DOCUMENTATION"
tk = toolkitHome.getToolkit(toolkitName=toolkitHome.RISKASSESSMENT, projectName=projectName)

# %%
tk.getConfig()
# Out:
# {'analysis_CacheCounter': 19,
#  'defaultBuildingDataSource': 'BNTL',
#  'defaultSRTM': 'SRTMGL1',
#  'defaultLandCover': 'Type-1',
#  'defaultTileServer': 'http://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
#  'defaultVersion': [0, 0, 1],
#  'RiskToolkit_H2S': [0, 0, 1],
#  'RiskToolkit_H2S_defaultVersion': [0, 0, 1],
#  'RiskToolkit_HCl_defaultVersion': [0, 0, 1],
#  'Project_HCl_defaultVersion': [0, 0, 1],
#  'HCl_defaultVersion': [0, 0, 1],
#  'lamas_defaultVersion': [0, 0, 1]}

# %%
tk.getMeasurementsDocumentsAsDict()['documents']
# Out:
# [{'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'toolkit': 'RiskAssessment',
#    'datasourceName': 'H2S',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': {'effectParameters': {'tenbergeCoefficient': 1},
#    'effects': {'AEGL10min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '10min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '106*mg/m**3'},
#        '2': {'threshold': '57.1*mg/m**3'},
#        '1': {'threshold': '1.05*mg/m**3'}}}},
#     'AEGL30min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '30min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '82.2*mg/m**3'},
#        '2': {'threshold': '44.6*mg/m**3'},
#        '1': {'threshold': '0.836*mg/m**3'}}}},
#     'AEGL60min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '60min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '69.7*mg/m**3'},
#        '2': {'threshold': '37.6*mg/m**3'},
#        '1': {'threshold': '0.711*mg/m**3'}}}},
#     'AEGL4hours': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '4h'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '51.6*mg/m**3'},
#        '2': {'threshold': '27.9*mg/m**3'},
#        '1': {'threshold': '0.502*mg/m**3'}}}},
#     'AEGL8hours': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '8h'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '43.2*mg/m**3'},
#        '2': {'threshold': '23.7*mg/m**3'},
#        '1': {'threshold': '0.46*mg/m**3'}}}},
#     'RegulatoryPAC60min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '10min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '69.7*mg/m**3'},
#        '2': {'threshold': '37.6*mg/m**3'},
#        '1': {'threshold': '0.711*mg/m**3'}}}}},
#    'physicalProperties': {}},
#   'dataFormat': 'JSON_dict'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'toolkit': 'RiskAssessment',
#    'datasourceName': 'HCl',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': {'effectParameters': {'tenbergeCoefficient': 1},
#    'effects': {'AEGL10min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '10min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '924.55*mg/m**3'},
#        '2': {'threshold': '149.12*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}},
#     'AEGL30min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '30min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '313.15*mg/m**3'},
#        '2': {'threshold': '64.12*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}},
#     'AEGL60min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '60min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '149*mg/m**3'},
#        '2': {'threshold': '32.81*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}},
#     'AEGL4hours': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '4h'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '38.77*mg/m**3'},
#        '2': {'threshold': '16.4*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}},
#     'AEGL8hours': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '8h'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '38.77*mg/m**3'},
#        '2': {'threshold': '16.4*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}},
#     'RegulatoryPAC60min': {'type': 'Threshold',
#      'calculator': {'MaxConcentration': {'sampling': '10min'}},
#      'parameters': {'type': 'Threshold',
#       'levels': ['3', '2', '1'],
#       'parameters': {'3': {'threshold': '149*mg/m**3'},
#        '2': {'threshold': '32.81*mg/m**3'},
#        '1': {'threshold': '2.68*mg/m**3'}}}}},
#    'physicalProperties': {'molecularWeight': '36.46*g/mol',
#     'sorptionCoefficient': '0.13333*cm/s',
#     'spreadFactor': 4.5,
#     'volatilityConstants': [8.5916, 2424.5, 273.16, 0],
#     'densityConstants': [1.0887, 0.00118, 25]}},
#   'dataFormat': 'JSON_dict'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'crs': 2039,
#    'BuildingHeightColumn': 'BLDG_HT',
#    'LandHeightColumns': 'HT_LAND',
#    'desc': {'crs': 2039,
#     'BuildingHeightColumn': 'BLDG_HT',
#     'LandHeightColumns': 'HT_LAND'},
#    'toolkit': 'Buildings',
#    'datasourceName': 'BNTL',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/GIS_BUILDING/BNTL-JERUSALEM/JERU-BLDG.shp',
#   'dataFormat': 'geopandas'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'toolkit': 'Tiles',
#    'datasourceName': 'localTileServer',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': 'http://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
#   'dataFormat': 'string'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'toolkit': 'experimentToolKit',
#    'datasourceName': 'IMS_experiment',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/development/hera_ims/.',
#   'dataFormat': 'string'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ARAD'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ARAD.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ARIEL'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ARIEL.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'toolkit': 'experimentToolKit',
#    'datasourceName': 'Haifa2014',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/experiment',
#   'dataFormat': 'string'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'Sonic', 'experimentName': 'Haifa2014'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/experiment/data/Sonic.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'TRH', 'experimentName': 'Haifa2014'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/experiment/data/TRH.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'desc': {},
#    'toolkit': 'TopographyToolkit',
#    'datasourceName': 'SRTMGL1',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/raster/N31E034.SRTMGL1.hgt',
#   'dataFormat': 'string'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'year': 2021,
#    'type': 1,
#    'desc': {'year': 2021, 'type': 1},
#    'toolkit': 'LandCoverToolkit',
#    'datasourceName': 'Type-1',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/Downloads/landcover/lc_mcd12q1v061.t2_c_500m_s_20210101_20211231_go_epsg.4326_v20230818.tif',
#   'dataFormat': 'geotiff'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'desc': {},
#    'toolkit': 'Demography',
#    'datasourceName': 'lamas',
#    'version': [0, 0, 1]},
#   'type': 'ToolkitDataSource',
#   'resource': '/home/salo/development/hera/hera/doc/jupyter/data/demography/pop-gush/Dan-population_lamas.shp',
#   'dataFormat': 'geopandas'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AVNE ETAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AVNE ETAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET ZAYDA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET ZAYDA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZEMAH'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZEMAH.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MEROM GOLAN PICMAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MEROM GOLAN PICMAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'YAVNEEL'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/YAVNEEL.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TAVOR KADOORIE'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TAVOR KADOORIE.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AFULA NIR HAEMEQ'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AFULA NIR HAEMEQ.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'QARNE SHOMERON'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/QARNE SHOMERON.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'JERUSALEM GIVAT RAM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/JERUSALEM GIVAT RAM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'JERUSALEM CENTRE'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/JERUSALEM CENTRE.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAR HARASHA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAR HARASHA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NETIV HALAMED HE'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NETIV HALAMED HE.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA PORT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA PORT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SHANI'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SHANI.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GILGAL'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GILGAL.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEWE ZOHAR UNI'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEWE ZOHAR UNI.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAZEVA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAZEVA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'PARAN 20060124'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/PARAN 20060124.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'YOTVATA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/YOTVATA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA REFINERIES'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA REFINERIES.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA UNIVERSITY'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA UNIVERSITY.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA TECHNION'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA TECHNION.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN KARMEL'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN KARMEL.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZIKHRON YAAQOV'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZIKHRON YAAQOV.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HADERA PORT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HADERA PORT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET DAGAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET DAGAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BESOR FARM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BESOR FARM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEER SHEVA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEER SHEVA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEER SHEVA UNI'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEER SHEVA UNI.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZEFAT HAR KENAAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZEFAT HAR KENAAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ELAT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ELAT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDOM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDOM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN HASHOFET'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN HASHOFET.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ELON'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ELON.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'QEVUZAT YAVNE'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/QEVUZAT YAVNE.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEIT JIMAL'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEIT JIMAL.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ROSH ZURIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ROSH ZURIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AFEQ'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AFEQ.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DOROT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DOROT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEGBA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEGBA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET DAGAN RAD'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET DAGAN RAD.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ITAMAR'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ITAMAR.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDE BOQER'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDE BOQER.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DEIR HANNA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DEIR HANNA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ROSH HANIQRA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ROSH HANIQRA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN HAHORESH'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN HAHORESH.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZOMET HANEGEV'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZOMET HANEGEV.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'LEV KINERET'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/LEV KINERET.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAFEZ HAYYIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAFEZ HAYYIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AMMIAD'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AMMIAD.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHDOD PORT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHDOD PORT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TEL AVIV COAST'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TEL AVIV COAST.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEWE YAAR'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEWE YAAR.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZOVA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZOVA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR BLUM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR BLUM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ESHHAR'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ESHHAR.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EDEN FARM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EDEN FARM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'PARAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/PARAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHQELON PORT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHQELON PORT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'METZOKE DRAGOT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/METZOKE DRAGOT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN GEDI'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN GEDI.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET DAGAN_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET DAGAN_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MAALE ADUMMIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MAALE ADUMMIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MAALE GILBOA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MAALE GILBOA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GAMLA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GAMLA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET HAARAVA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET HAARAVA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEOT SMADAR'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEOT SMADAR.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR NAHUM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR NAHUM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GAT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GAT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ELON_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ELON_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ARAD_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ARAD_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR GILADI'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR GILADI.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ARIEL_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ARIEL_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHDOD PORT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHDOD PORT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BESOR FARM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BESOR FARM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DOROT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DOROT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN HAHORESH_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN HAHORESH_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'QARNE SHOMERON_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/QARNE SHOMERON_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'JERUSALEM CENTRE_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/JERUSALEM CENTRE_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'JERUSALEM GIVAT RAM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/JERUSALEM GIVAT RAM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDOM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDOM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDE BOQER_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDE BOQER_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEGBA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEGBA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TEL YOSEF 20141223'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TEL YOSEF 20141223.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NAHSHON'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NAHSHON.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GALED'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GALED.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MERHAVYA 20170702'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MERHAVYA 20170702.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MIZPE RAMON 20120927'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MIZPE RAMON 20120927.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HARASHIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HARASHIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SHAARE TIQWA 20161205'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SHAARE TIQWA 20161205.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AVDAT'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AVDAT.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NIZZAN'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NIZZAN.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAKFAR HAYAROK'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAKFAR HAYAROK.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GILGAL_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GILGAL_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ITAMAR_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ITAMAR_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAR HARASHA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAR HARASHA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET HAARAVA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET HAARAVA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MAALE ADUMMIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MAALE ADUMMIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZOVA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZOVA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NAHSHON_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NAHSHON_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAFEZ HAYYIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAFEZ HAYYIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'QEVUZAT YAVNE_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/QEVUZAT YAVNE_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GAT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GAT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ROSH ZURIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ROSH ZURIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NETIV HALAMED HE_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NETIV HALAMED HE_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEIT JIMAL_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEIT JIMAL_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'METZOKE DRAGOT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/METZOKE DRAGOT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN GEDI_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN GEDI_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHQELON PORT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHQELON PORT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SHANI_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SHANI_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEER SHEVA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEER SHEVA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZOMET HANEGEV_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZOMET HANEGEV_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAZEVA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAZEVA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MIZPE RAMON_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MIZPE RAMON_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'PARAN_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/PARAN_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HARASHIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HARASHIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TEL AVIV COAST_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TEL AVIV COAST_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AVNE ETAN_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AVNE ETAN_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BET ZAYDA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BET ZAYDA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZEMAH_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZEMAH_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MEROM GOLAN PICMAN_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MEROM GOLAN PICMAN_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'YAVNEEL_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/YAVNEEL_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TAVOR KADOORIE_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TAVOR KADOORIE_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AFULA NIR HAEMEQ_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AFULA NIR HAEMEQ_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EDEN FARM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EDEN FARM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'YOTVATA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/YOTVATA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA REFINERIES_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA REFINERIES_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA UNIVERSITY_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA UNIVERSITY_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HAIFA TECHNION_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HAIFA TECHNION_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN KARMEL_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN KARMEL_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ZIKHRON YAAQOV_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ZIKHRON YAAQOV_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'HADERA PORT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/HADERA PORT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ELAT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ELAT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EN HASHOFET_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EN HASHOFET_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AFEQ_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AFEQ_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DEIR HANNA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DEIR HANNA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ROSH HANIQRA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ROSH HANIQRA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AMMIAD_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AMMIAD_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEWE YAAR_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEWE YAAR_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR BLUM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR BLUM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ESHHAR_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ESHHAR_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'GAMLA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/GAMLA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MAALE GILBOA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MAALE GILBOA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEOT SMADAR_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEOT SMADAR_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR NAHUM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR NAHUM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AVDAT_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AVDAT_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NIZZAN_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NIZZAN_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EZUZ'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EZUZ.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SHAVE ZIYYON'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SHAVE ZIYYON.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'EZUZ_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/EZUZ_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SHAVE ZIYYON_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SHAVE ZIYYON_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'KEFAR GILADI_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/KEFAR GILADI_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DAFNA 20191106'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DAFNA 20191106.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEVATIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEVATIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'LAHAV'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/LAHAV.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'LAHAV_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/LAHAV_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DAFNA_1m 20191106'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DAFNA_1m 20191106.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AYYELET HASHAHAR'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AYYELET HASHAHAR.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'AYYELEY HASHAHAR_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/AYYELEY HASHAHAR_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MASSADA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MASSADA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDE ELIYYAHU'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDE ELIYYAHU.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'SEDE ELIYYAHU_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/SEDE ELIYYAHU_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NEVATIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NEVATIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'MIZPE RAMON'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/MIZPE RAMON.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TEL YOSEF'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TEL YOSEF.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHALIM'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHALIM.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEER SHEVA BGU'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEER SHEVA BGU.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'BEER SHEVA BGU_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/BEER SHEVA BGU_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'TEL YOSEF_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/TEL YOSEF_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'ASHALIM_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/ASHALIM_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DAFNA_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DAFNA_1m.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'DAFNA'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/DAFNA.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NAZARETH'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NAZARETH.parquet',
#   'dataFormat': 'parquet'},
#  {'_cls': 'Metadata.Measurements',
#   'projectName': 'DOCUMENTATION',
#   'desc': {'deviceType': 'STATION',
#    'experimentName': 'IMS_experiment',
#    'deviceName': 'NAZARET_1m'},
#   'type': 'Experiment_rawData',
#   'resource': '/home/salo/development/hera_ims/data/NAZARET_1m.parquet',
#   'dataFormat': 'parquet'}]

# %%
tk.getConfig().get("HCl")
