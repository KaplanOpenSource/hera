# %% [markdown]
# # Loading a template
#
# In order to use the LSM fortran code, we have to load a template from the database.
# The templates defer by their parameterization.
# The templates may be loaded to the database using hera-lsm:
#
# hera-LSM-load-template v1-general documentation
#
# The available templates in the project can be viewed using the LSM toolkit:

# %%
from hera import toolkitHome

projectName = "documentation"
toolkitName = "LSM"
LSM  = toolkitHome.getToolkit(projectName=projectName,toolkitName=toolkitName)
LSM.listTemplates()
# Out:
#                     variable  \
# 0                    version
# 1                    version
# 2                    version
# 3                    version
# 4                    toolkit
# 5                    toolkit
# 6                    toolkit
# 7                    toolkit
# 8                   template
# 9                   template
# 10                  template
# 11                  template
# 12               modelFolder
# 13               modelFolder
# 14               modelFolder
# 15               modelFolder
# 16                        id
# 17                        id
# 18                        id
# 19                        id
# 20               projectName
# 21               projectName
# 22               projectName
# 23               projectName
# 24          params__TopoFile
# 25          params__TopoFile
# 26          params__TopoFile
# 27          params__TopoFile
# 28              params__flat
# 29              params__flat
# ..                       ...
# 102           params__savedy
# 103           params__savedy
# 104           params__savedz
# 105           params__savedz
# 106           params__savedz
# 107           params__savedz
# 108     params__StationsFile
# 109     params__StationsFile
# 110     params__StationsFile
# 111     params__StationsFile
# 112  params__homogeneousWind
# 113  params__homogeneousWind
# 114  params__homogeneousWind
# 115  params__homogeneousWind
# 116      params__particles3D
# 117      params__particles3D
# 118      params__particles3D
# 119      params__particles3D
# 120           params__wind3D
# 121           params__wind3D
# 122           params__wind3D
# 123           params__wind3D
# 124           params__n_vdep
# 125           params__n_vdep
# 126           params__n_vdep
# 127           params__n_vdep
# 128                     name
# 129                     name
# 130                     name
# 131                     name
#
#                                                  value
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                  LSM
# 5                                                  LSM
# 6                                                  LSM
# 7                                                  LSM
# 8                                           v1-general
# 9                                           v1-general
# 10                                                 NaN
# 11                                                 NaN
# 12   /home/eyal/Development/hera-lsm/fortran/templa...
# 13   /home/eyal/Development/hera-lsm/fortran/templa...
# 14   /home/eyal/Development/hera-lsm/fortran/templa...
# 15   /home/eyal/Development/hera-lsm/fortran/templa...
# 16                            606969333ad719c3c300ce08
# 17                            606969333ad719c3c300ce08
# 18                            6069701ff1d6d2e8ed8abf49
# 19                            6069701ff1d6d2e8ed8abf49
# 20                                       documentation
# 21                                       documentation
# 22                                       documentation
# 23                                       documentation
# 24                                         'INPUTFLAT'
# 25                                         'INPUTFLAT'
# 26                                         'INPUTFLAT'
# 27                                         'INPUTFLAT'
# 28                                              .TRUE.
# 29                                              .TRUE.
# ..                                                 ...
# 102                                                 10
# 103                                                 10
# 104                                                 10
# 105                                                 10
# 106                                                 10
# 107                                                 10
# 108                            'INPUT_STAT_DATA_HAIFA'
# 109                            'INPUT_STAT_DATA_HAIFA'
# 110                            'INPUT_STAT_DATA_HAIFA'
# 111                            'INPUT_STAT_DATA_HAIFA'
# 112                                             .TRUE.
# 113                                             .TRUE.
# 114                                             .TRUE.
# 115                                             .TRUE.
# 116                                            .FALSE.
# 117                                            .FALSE.
# 118                                            .FALSE.
# 119                                            .FALSE.
# 120                                            .FALSE.
# 121                                            .FALSE.
# 122                                            .FALSE.
# 123                                            .FALSE.
# 124                                                  0
# 125                                                  0
# 126                                                  0
# 127                                                  0
# 128                                                NaN
# 129                                                NaN
# 130                                         v1-general
# 131                                         v1-general
#
# [132 rows x 2 columns]

# %% [markdown]
# A template object can be loaded by quering its parameters or by its name:

# %%
template = LSM.getTemplates(params__windDir=270)
template = LSM.getTemplateByName("v1-general")
